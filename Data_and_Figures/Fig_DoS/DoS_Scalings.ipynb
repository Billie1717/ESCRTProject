# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append("..")
import pandas
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import FormatStrFormatter
from matplotlib.colors import LogNorm
from matplotlib.colors import TwoSlopeNorm
import warnings
warnings.filterwarnings("ignore")
import seaborn as sns; sns.set_theme()
datadir = '/Users/billiemeadowcroft/Dropbox/PhDGithub/RemoteESCRT/Data_and_Figures/Fig_DoS/Data/'
plotsdir = '/Users/billiemeadowcroft/Dropbox/PhDGithub/RemoteESCRT/Data_and_Figures/Fig_DoS/Plots/'
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
def DoS(Maxof0,Maxof1,Maxof2,LastProb0,LastProb1,LastProb2,P1t0,P2t0,P0t1,P2t1,Kd1s,Kd2s):
    #Defining our DoS parameter
    thing1 = np.add(np.divide(P1t0,Maxof0), np.divide(P2t0,Maxof0))
    thing2 = np.add(np.divide(P0t1,Maxof1),np.divide(P2t1,Maxof1))
    firstT = np.add(thing1,thing2)
    secondT = 4*np.add(np.divide(LastProb0,Maxof0),np.divide(LastProb1,Maxof1))
    thing4 = np.add(np.divide(Maxof0,Maxof2),np.divide(Maxof1,Maxof2))
    thirdT = 2*abs(np.add(2,-thing4))
    
    fourthT = np.add(1,-np.divide(LastProb2,Maxof2))
    thing5add4 = np.add(fourthT,thirdT)
    lastTs = np.add(thing5add4,secondT)
    DoS_ = (1/10)*(np.add(firstT,lastTs))
    DoS = np.divide(1,DoS_)
    #re-shaping our columns for appropriate arrays
    DoS_arr= DoS.values.reshape(Kd1s,Kd2s)
    
    return DoS_arr/2

# %% [markdown]
# ## Plotting Binding energy

# %%
def DoS(Maxof0,Maxof1,Maxof2,LastProb0,LastProb1,LastProb2,P1t0,P2t0,P0t1,P2t1,Kd1s,Kd2s):
    #Defining our DoS parameter
    thing1 = np.add(np.divide(P1t0,Maxof0), np.divide(P2t0,Maxof0))
    thing2 = np.add(np.divide(P0t1,Maxof1),np.divide(P2t1,Maxof1))
    firstT = np.add(thing1,thing2)
    secondT = 4*np.add(np.divide(LastProb0,Maxof0),np.divide(LastProb1,Maxof1))
    thing4 = np.add(np.divide(Maxof0,Maxof2),np.divide(Maxof1,Maxof2))
    thirdT = 2*abs(np.add(2,-thing4))
    
    fourthT = np.add(1,-np.divide(LastProb2,Maxof2))
    thing5add4 = np.add(fourthT,thirdT)
    lastTs = np.add(thing5add4,secondT)
    DoS_ = (1/10)*(np.add(firstT,lastTs))
    DoS = np.divide(1,DoS_)
    #re-shaping our columns for appropriate arrays
    DoS_arr= DoS.values.reshape(Kd1s,Kd2s)
    
    return DoS_arr/1.8

#loc = datadir+'bind12/' +'bindCharCrv'
#loc = datadir+'Tube/Diss/' +'Tube1_DissOUT'loc = datadir +'Energies12CharCrv'
loc = datadir +'Energies12CharCrv'
n1 = 400
k1= 20
k2= 20
Maxof0_ = pandas.read_csv(loc + ".txt", header = None, sep=',', usecols= [0])#.lstrip('(')#.rstrip(']')
Maxof0__ = np.zeros(n1)
for i in range(n1):
    Maxof0__[i] = Maxof0_[0][i].lstrip('(')
Maxof0 = Maxof0__
Maxof1 = pandas.read_csv(loc + ".txt", header = None, sep=',', usecols= [1])
Maxof2 = pandas.read_csv(loc + ".txt", header = None, sep=',', usecols= [2])
LastProb0 = pandas.read_csv(loc + ".txt", header = None, sep=',', usecols= [3])
LastProb1 = pandas.read_csv(loc + ".txt", header = None, sep=',', usecols= [4])
LastProb2 = pandas.read_csv(loc + ".txt", header = None, sep=',', usecols= [5])
P1t0 = pandas.read_csv(loc + ".txt", header = None, sep=',', usecols= [6])
P2t0 = pandas.read_csv(loc + ".txt", header = None, sep=',', usecols= [7])
P0t1 = pandas.read_csv(loc + ".txt", header = None, sep=',', usecols= [8])
P2t1_ = pandas.read_csv(loc + ".txt", header = None, sep=',', usecols= [9])
P2t1__ = np.zeros(n1)
for j in range(n1):
    P2t1__[j] = P2t1_[9][j].rstrip(') ')
P2t1 = P2t1__.reshape(n1,1)
Maxof0 = Maxof0__.reshape(n1,1)

DoS = DoS(Maxof0,Maxof1,Maxof2,LastProb0,LastProb1,LastProb2,P1t0,P2t0,P0t1,P2t1,k1,k2)[0:10,6:13]

fig1 = plt.figure(figsize = (7,9))
x = np.arange(6, 13, 1)
y = np.arange(1, 11, 1)
X=np.round(x,1)
Y=np.round(y,1)

sns.set(font_scale=1.2)

ax = sns.heatmap(DoS,xticklabels=X, yticklabels=Y,cmap="PuBuGn",cbar_kws={'label': 'DoS'},vmin=0, vmax=1)

ax.invert_yaxis()
plt.xlabel("$E_{2}^{\mathrm{adh}}/E_{0}^{\mathrm{adh}}$", fontsize = 14) 
plt.ylabel("$E_{1}^{\mathrm{adh}}/E_{0}^{\mathrm{adh}}$", fontsize = 14)  
plt.title("Adhesion energy", fontsize = 14)  
#n = 2  # Keeps every 2nd label


#[l.set_visible(False) for (i,l) in enumerate(ax.xaxis.get_ticklabels()) if i % n != 0]


scX = np.arange(0,11.5)
scY = np.arange(0,11.5)
scX2 = np.arange(0,12.5)
Scale1_ = np.multiply(scX,1)
Scale1 = np.add(Scale1_,4)

Scale2 = np.ones(13)*2.1
Scale3 = np.ones(12)*2.3
ax2=plt.twinx()
ax2.grid(False)
ax2.plot(scX,Scale1, color = 'tab:pink', linewidth = 3, label = r'$E_{1}^{\mathrm{adh}}-E_{1}^{\mathrm{mem}} < E_{2}^{\mathrm{adh}}-E_{2}^{\mathrm{mem}}$')
ax2.plot(scX2,Scale2, color = 'gold', linewidth = 3, label = r'$E_{1}^{\mathrm{adh}} > E_{1}^{\mathrm{mem}}$')
#ax2.plot(Scale3,scY, color = 'orange', linewidth = 3, label = r'$E_{2}^{\mathrm{adh}} > E_{2}^{\mathrm{mem}}$')
ax2.set_ylim(1,10)
ax2.set_yticklabels([])
ax2.set_yticks([])
plt.gcf().subplots_adjust(bottom=0.5)

ax2.legend(loc = (0.2,-0.6), frameon = False, fontsize = 14)

zm= np.zeros((10,11))
for i in range(10):
        for j in range(11):
            if i < j+4 and i>1.9:
                zm[i][j] = 1
            else:
                zm[i][j] = 0
cond1 = (zm == 0)
mZ1 = np.ma.array(zm, mask=cond1)
hatch = ax2.pcolor(mZ1, hatch='//', alpha=0.,shading='auto')

#ax.set_yticks([0.5,2.5,4.5,6.5,8.5])
#ax.set_yticklabels(['3','9','16','22','28'])
#ax.set_xticks([0.5,2.5,4.5,6.5,8.5,10.5])
#ax.set_xticklabels(['3','16','28','41','53','66'])
fname  = 'ScaleEn.pdf'
fig1.savefig(plotsdir+fname)
print(DoS)
print(np.shape(DoS))
# Out:
# [[0.07378959 0.08776979 0.20499384 0.31093768 0.53679617 0.68198265
#   0.68262324]
#  [0.06000385 0.09974139 0.20775436 0.31878591 0.67462805 0.76703817
#   0.80230631]
#  [0.06399134 0.09356858 0.18971812 0.34331169 0.82538154 1.00691999
#   0.99074659]
#  [0.06593299 0.08985729 0.21378669 0.40481838 0.77085978 0.75713658
#   0.70026178]
#  [0.06581856 0.13021698 0.22522058 0.43964632 0.64200854 0.71465045
#   0.64568271]
#  [0.0990351  0.14956395 0.25335351 0.42235315 0.61359828 0.58397416
#   0.58296032]
#  [0.08828449 0.15555802 0.27333236 0.46844865 0.61851272 0.5952282
#   0.53684702]
#  [0.10492694 0.15268457 0.29354962 0.45703184 0.56855199 0.57633983
#   0.54806684]
#  [0.09423251 0.15910027 0.30108119 0.48419289 0.62883138 0.59343193
#   0.54563334]
#  [0.10750282 0.15529711 0.32309039 0.46899219 0.6147808  0.58784975
#   0.55974789]]
# (10, 7)

# %% [markdown]
# # Curvatures

# %%
def DoS(Maxof0,Maxof1,Maxof2,LastProb0,LastProb1,LastProb2,P1t0,P2t0,P0t1,P2t1,Kd1s,Kd2s):
    #Defining our DoS parameter
    thing1 = np.add(np.divide(P1t0,Maxof0), np.divide(P2t0,Maxof0))
    thing2 = np.add(np.divide(P0t1,Maxof1),np.divide(P2t1,Maxof1))
    firstT = np.add(thing1,thing2)
    secondT = 4*np.add(np.divide(LastProb0,Maxof0),np.divide(LastProb1,Maxof1))
    thing4 = np.add(np.divide(Maxof0,Maxof2),np.divide(Maxof1,Maxof2))
    thirdT = 2*abs(np.add(2,-thing4))
    
    fourthT = np.add(1,-np.divide(LastProb2,Maxof2))
    thing5add4 = np.add(fourthT,thirdT)
    lastTs = np.add(thing5add4,secondT)
    DoS_ = (1/10)*(np.add(firstT,lastTs))
    DoS = np.divide(1,DoS_)
    #re-shaping our columns for appropriate arrays
    DoS_arr= DoS.values.reshape(Kd1s,Kd2s)
    
    return DoS_arr/1.8

loc = datadir +'Curve_CharCrv'
n1 = 400
k1= 20
k2= 20
Maxof0_ = pandas.read_csv(loc + ".txt", header = None, sep=',', usecols= [0])#.lstrip('(')#.rstrip(']')
Maxof0__ = np.zeros(n1)
for i in range(n1):
    Maxof0__[i] = Maxof0_[0][i].lstrip('(')
Maxof0 = Maxof0__
Maxof1 = pandas.read_csv(loc + ".txt", header = None, sep=',', usecols= [1])
Maxof2 = pandas.read_csv(loc + ".txt", header = None, sep=',', usecols= [2])
LastProb0 = pandas.read_csv(loc + ".txt", header = None, sep=',', usecols= [3])
LastProb1 = pandas.read_csv(loc + ".txt", header = None, sep=',', usecols= [4])
LastProb2 = pandas.read_csv(loc + ".txt", header = None, sep=',', usecols= [5])
P1t0 = pandas.read_csv(loc + ".txt", header = None, sep=',', usecols= [6])
P2t0 = pandas.read_csv(loc + ".txt", header = None, sep=',', usecols= [7])
P0t1 = pandas.read_csv(loc + ".txt", header = None, sep=',', usecols= [8])
P2t1_ = pandas.read_csv(loc + ".txt", header = None, sep=',', usecols= [9])
P2t1__ = np.zeros(n1)
for j in range(n1):
    P2t1__[j] = P2t1_[9][j].rstrip(') ')
P2t1 = P2t1__.reshape(n1,1)
Maxof0 = Maxof0__.reshape(n1,1)
#print(Maxof0)
DoSC = DoS(Maxof0,Maxof1,Maxof2,LastProb0,LastProb1,LastProb2,P1t0,P2t0,P0t1,P2t1,k1,k2)

fig5 = plt.figure(figsize = (7,11))
y = np.arange(0.5, 9.9, 0.5) 
x = np.arange(0.5, 9.9, 0.5) 

y1 = y
x1 = x
Y = np.round(y1,2)
X = np.round(x1,2)
sns.set(font_scale=1.2)

ax = sns.heatmap(DoSC,xticklabels=x, yticklabels=y,cmap="PuBuGn",cbar_kws={'label': 'DoS'},vmin=0.2, vmax=1)
ax.invert_yaxis()
plt.xlabel(r"$c_{2}/c_{0}$", fontsize = 14) 
plt.ylabel(r"$c_{1}/c_{0}$", fontsize = 14) 
plt.title(r"Curvature", fontsize = 14) 
n = 4  # Keeps every 2nd label
[l.set_visible(False) for (i,l) in enumerate(ax.xaxis.get_ticklabels()) if i % n != 0]

#m = 4  # Keeps every 2nd label
#[l.set_visible(False) for (i,l) in enumerate(ax.yaxis.get_ticklabels()) if i % m != 0]

textstr = '\n'.join((
    r'Staged assembly and disassembly: DoS $\approx$ 1',
    r'         No sequential peaks: DoS $\approx$ 0'))

ax.text(0.05, 1.3, textstr, transform=ax.transAxes, fontsize=14,verticalalignment='top')
scX = np.arange(0,20.5)
scY = np.arange(0,20.5)
scX2 = np.arange(0,12.5)
Scale1_ = np.multiply(scX,0.5)
Scale4_ = np.multiply(scX,0.5)
Scale1u = np.add(Scale1_,-3.3)
Scale4u = np.add(Scale4_,-1.3)
Scale1l = np.add(Scale1_,-6.7)

Scale2y = np.ones(21)*2.4
Scale2x = np.ones(21)*3.5
Scale3 = np.ones(21)*3.9
ax2=plt.twinx()
ax2.grid(False)

#ax2.plot(scX,Scale1u, color = 'tab:pink', linewidth = 3, label = r'$E_{2/1}^{\mathrm{adh}}-E_{2/1}^{\mathrm{mem}} >/< \ \frac{\kappa}{2} (c_{1}-c_{2})^{2}$')
#ax2.plot(scX,Scale1l, color = 'tab:pink', linewidth = 3)
ax2.plot(scX,Scale4u, color = 'tab:pink', linewidth = 3, label = r'$E_{1}^{\mathrm{adh}} < \ \frac{\kappa}{2} (c_{1}-c_{2})^{2}$')

ax2.plot(scX,Scale2y, color = 'gold', linewidth = 3, label = r'$E_{0}^{\mathrm{adh}} < \frac{\kappa}{2} (c_{1/2}-c_{0})^{2}$')
ax2.plot(Scale2x,scY, color = 'gold', linewidth = 3)
ax2.plot(scX,Scale3, color = 'orange', linewidth = 3, label = r'$E_{1}^{\mathrm{adh}} > \frac{\kappa}{2}(c_{1}-c_{0})^{2}$')
ax2.set_ylim(1,10)
ax2.set_yticklabels([])
ax2.set_yticks([])
ax2.legend(loc = (0.2,-0.6), frameon = False, fontsize = 14)

zm= np.zeros((20,20))
for i in range(20):
        for j in range(20):
            if j > 2.2 and i > 1.9 and i<0.5*j-1.5 and i < 3.1:
                zm[i][j] = 1
            else:
                zm[i][j] = 0
cond1 = (zm == 0)
mZ1 = np.ma.array(zm, mask=cond1)
hatch = ax2.pcolor(mZ1, hatch='//', alpha=0.,shading='auto')

#m = 4  # Keeps every 2nd label
#[l.set_visible(False) for (i,l) in enumerate(ax2.yaxis.get_ticklabels()) if i % m != 0]
#[l.set_visible(False) for (i,l) in enumerate(ax.yaxis.get_ticklabels()) if i % m != 0]
plt.gcf().subplots_adjust(left=0.15)
plt.gcf().subplots_adjust(bottom=0.5)
plt.gcf().subplots_adjust(top=0.8)

ax.set_yticks([3,7,11,15,19])
ax.set_yticklabels(['2','4','6','8','10'])
#ax.set_xticks([2,6,10,14,18],rotation = 90)
#ax.set_xticklabels(['1','3','5','7','9'],rotation = 90)
#ax.xticks(rotation = 90)

fname  = 'ScaleCu.pdf'
fig5.savefig(plotsdir+fname)
